# %% [markdown]
# I hate this goddamnd code

# %%
#Imports HEre
import requests
from __future__ import print_function
import time
import swagger_client
from swagger_client.rest import ApiException
from pprint import pprint
import json

# %%
#Configs and Nonsense
mkey = '49880dc5499b46fa967202042232107'

configuration = swagger_client.Configuration()
configuration.api_key['key'] = mkey

# %% [markdown]
# Ok so like in this spot im gonna try to pull down the data and yeet it into a json file, may god have mercy in my soul

# %% [markdown]
# # Configure API key authorization: ApiKeyAuth
#
# configuration = swagger_client.Configuration()
# configuration.api_key['key'] = 'YOUR_API_KEY'
#
#
# # Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
# # configuration.api_key_prefix['key'] = 'Bearer'
#
# # create an instance of the API class
#
#
# api_instance = swagger_client.APIsApi(swagger_client.ApiClient(configuration))
# q = 'q_example' # str | Pass US Zipcode, UK Postcode, Canada Postalcode, IP address, Latitude/Longitude (decimal degree) or city name. Visit [request parameter section](https://www.weatherapi.com/docs/#intro-request) to learn more.
# days = 56 # int | Number of days of weather forecast. Value ranges from 1 to 14
# dt = '2013-10-20' # date | Date should be between today and next 14 day in yyyy-MM-dd format. e.g. '2015-01-01'  (optional)
# unixdt = 56 # int | Please either pass 'dt' or 'unixdt' and not both in same request. unixdt should be between today and next 14 day in Unix format. e.g. 1490227200  (optional)
# hour = 56 # int | Must be in 24 hour. For example 5 pm should be hour=17, 6 am as hour=6  (optional)
# lang = 'lang_example' # str | Returns 'condition:text' field in API in the desired language.<br /> Visit [request parameter section](https://www.weatherapi.com/docs/#intro-request) to check 'lang-code'.  (optional)
#
# # This Part is the Actual Code
#
# api_instance = swagger_client.APIsApi(swagger_client.ApiClient(configuration))
#
#
# try:
#     # Forecast API
#     api_response = api_instance.forecast_weather(q, days, dt=dt, unixdt=unixdt, hour=hour, lang=lang)
#     pprint(api_response)
# except ApiException as e:
#     print("Exception when calling APIsApi->forecast_weather: %s\n" % e)

# %%
api_instance = swagger_client.APIsApi(swagger_client.ApiClient(configuration))
api_response = api_instance.forecast_weather('Tucson', 14)
print(api_response)

#This was code from first try

# %%
try:
    # Forecast API
    api_response = api_instance.forecast_weather('Tucson', 14)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling APIsApi->forecast_weather: %s\n" % e)
# Out:
# {'alerts': None,
#  'current': {'air_quality': None,
#              'cloud': 50,
#              'condition': {'code': 1003,
#                            'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                            'text': 'Partly cloudy'},
#              'feelslike_c': 33,
#              'feelslike_f': 91.8,
#              'gust_kph': 43.6,
#              'gust_mph': 27.1,
#              'humidity': 34,
#              'is_day': 0,
#              'last_updated': '2023-07-21 22:15',
#              'last_updated_epoch': 1690002900,
#              'precip_in': 0,
#              'precip_mm': 0,
#              'pressure_in': 29.97,
#              'pressure_mb': 1015,
#              'temp_c': 31.7,
#              'temp_f': 89.1,
#              'uv': 1,
#              'vis_km': 16,
#              'vis_miles': 9,
#              'wind_degree': 190,
#              'wind_dir': 'S',
#              'wind_kph': 38.9,
#              'wind_mph': 24.2},
#  'forecast': {'forecastday': [{'_date': datetime.date(2023, 7, 21),
#                                'astro': {'moon_illumination': '9',
#                                          'moon_phase': 'Waxing Crescent',
#                                          'moonrise': '08:56 AM',
#                                          'moonset': '10:04 PM',
#                                          'sunrise': '05:32 AM',
#                                          'sunset': '07:29 PM'},
#                                'date_epoch': 1689897600,
#                                'day': {'avghumidity': 30,
#                                        'avgtemp_c': 34.1,
#                                        'avgtemp_f': 93.4,
#                                        'avgvis_km': 9,
#                                        'avgvis_miles': 6,
#                                        'condition': {'code': 1063,
#                                                      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#                                                      'text': 'Patchy rain '
#                                                              'possible'},
#                                        'daily_chance_of_rain': 88,
#                                        'daily_chance_of_snow': 0,
#                                        'daily_will_it_rain': 1,
#                                        'daily_will_it_snow': 0,
#                                        'maxtemp_c': 43.8,
#                                        'maxtemp_f': 110.8,
#                                        'maxwind_kph': 36.7,
#                                        'maxwind_mph': 22.8,
#                                        'mintemp_c': 24.7,
#                                        'mintemp_f': 76.5,
#                                        'totalprecip_in': 0,
#                                        'totalprecip_mm': 0,
#                                        'uv': 7},
#                                'hour': [{'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 4,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 5.9,
#                                          'dewpoint_f': 42.6,
#                                          'feelslike_c': 31.2,
#                                          'feelslike_f': 88.2,
#                                          'gust_kph': 10.8,
#                                          'gust_mph': 6,
#                                          'heatindex_c': 31.2,
#                                          'heatindex_f': 88.2,
#                                          'humidity': 18,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 33.3,
#                                          'temp_f': 91.9,
#                                          'time': '2023-07-21 00:00',
#                                          'time_epoch': 1689922800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 202,
#                                          'wind_dir': 'SSW',
#                                          'wind_kph': 6.5,
#                                          'wind_mph': 4.0,
#                                          'windchill_c': 33.3,
#                                          'windchill_f': 91.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 11,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 6.3,
#                                          'dewpoint_f': 43.3,
#                                          'feelslike_c': 29.9,
#                                          'feelslike_f': 85.8,
#                                          'gust_kph': 18.4,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 29.9,
#                                          'heatindex_f': 85.8,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.8,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 32.1,
#                                          'temp_f': 89.8,
#                                          'time': '2023-07-21 01:00',
#                                          'time_epoch': 1689926400,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 204,
#                                          'wind_dir': 'SSW',
#                                          'wind_kph': 11.9,
#                                          'wind_mph': 7.4,
#                                          'windchill_c': 32.1,
#                                          'windchill_f': 89.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 14,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 6.6,
#                                          'dewpoint_f': 43.9,
#                                          'feelslike_c': 28.9,
#                                          'feelslike_f': 84.0,
#                                          'gust_kph': 16.6,
#                                          'gust_mph': 10,
#                                          'heatindex_c': 28.9,
#                                          'heatindex_f': 84.0,
#                                          'humidity': 22,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 30.9,
#                                          'temp_f': 87.6,
#                                          'time': '2023-07-21 02:00',
#                                          'time_epoch': 1689930000,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 238,
#                                          'wind_dir': 'WSW',
#                                          'wind_kph': 10.4,
#                                          'wind_mph': 6.5,
#                                          'windchill_c': 30.9,
#                                          'windchill_f': 87.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 38,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Partly cloudy'},
#                                          'dewpoint_c': 6.8,
#                                          'dewpoint_f': 44.2,
#                                          'feelslike_c': 27.8,
#                                          'feelslike_f': 82.0,
#                                          'gust_kph': 18.4,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 27.8,
#                                          'heatindex_f': 82.0,
#                                          'humidity': 24,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 29.6,
#                                          'temp_f': 85.3,
#                                          'time': '2023-07-21 03:00',
#                                          'time_epoch': 1689933600,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 274,
#                                          'wind_dir': 'W',
#                                          'wind_kph': 12.2,
#                                          'wind_mph': 7.6,
#                                          'windchill_c': 29.6,
#                                          'windchill_f': 85.3},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 65,
#                                          'condition': {'code': 1006,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#                                                        'text': 'Cloudy'},
#                                          'dewpoint_c': 7.5,
#                                          'dewpoint_f': 45.5,
#                                          'feelslike_c': 27.3,
#                                          'feelslike_f': 81.1,
#                                          'gust_kph': 9.0,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 27.3,
#                                          'heatindex_f': 81.1,
#                                          'humidity': 26,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 28.8,
#                                          'temp_f': 83.8,
#                                          'time': '2023-07-21 04:00',
#                                          'time_epoch': 1689937200,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 296,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 7.2,
#                                          'wind_mph': 4.5,
#                                          'windchill_c': 28.8,
#                                          'windchill_f': 83.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 44,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Partly cloudy'},
#                                          'dewpoint_c': 11.5,
#                                          'dewpoint_f': 52.7,
#                                          'feelslike_c': 26.7,
#                                          'feelslike_f': 80.1,
#                                          'gust_kph': 7.9,
#                                          'gust_mph': 4,
#                                          'heatindex_c': 26.7,
#                                          'heatindex_f': 80.1,
#                                          'humidity': 38,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.86,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 27.0,
#                                          'temp_f': 80.6,
#                                          'time': '2023-07-21 05:00',
#                                          'time_epoch': 1689940800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 311,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 5.8,
#                                          'wind_mph': 3.6,
#                                          'windchill_c': 27.0,
#                                          'windchill_f': 80.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.9,
#                                          'dewpoint_f': 60.6,
#                                          'feelslike_c': 26.0,
#                                          'feelslike_f': 78.8,
#                                          'gust_kph': 10.4,
#                                          'gust_mph': 6,
#                                          'heatindex_c': 26.0,
#                                          'heatindex_f': 78.8,
#                                          'humidity': 58,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.9,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 24.9,
#                                          'temp_f': 76.8,
#                                          'time': '2023-07-21 06:00',
#                                          'time_epoch': 1689944400,
#                                          'uv': 6,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 346,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 7.6,
#                                          'wind_mph': 4.7,
#                                          'windchill_c': 24.9,
#                                          'windchill_f': 76.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.8,
#                                          'feelslike_c': 26.1,
#                                          'feelslike_f': 79.0,
#                                          'gust_kph': 9.4,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 26.1,
#                                          'heatindex_f': 79.0,
#                                          'humidity': 63,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 24.7,
#                                          'temp_f': 76.5,
#                                          'time': '2023-07-21 07:00',
#                                          'time_epoch': 1689948000,
#                                          'uv': 6,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 356,
#                                          'wind_dir': 'N',
#                                          'wind_kph': 7.2,
#                                          'wind_mph': 4.5,
#                                          'windchill_c': 24.7,
#                                          'windchill_f': 76.5},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.8,
#                                          'feelslike_c': 27.8,
#                                          'feelslike_f': 82.0,
#                                          'gust_kph': 9.4,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 27.8,
#                                          'heatindex_f': 82.0,
#                                          'humidity': 56,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 26.8,
#                                          'temp_f': 80.2,
#                                          'time': '2023-07-21 08:00',
#                                          'time_epoch': 1689951600,
#                                          'uv': 7,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 347,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 8.3,
#                                          'wind_mph': 5.1,
#                                          'windchill_c': 26.8,
#                                          'windchill_f': 80.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 16.2,
#                                          'dewpoint_f': 61.2,
#                                          'feelslike_c': 29.6,
#                                          'feelslike_f': 85.3,
#                                          'gust_kph': 11.9,
#                                          'gust_mph': 7,
#                                          'heatindex_c': 29.6,
#                                          'heatindex_f': 85.3,
#                                          'humidity': 46,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 29.1,
#                                          'temp_f': 84.4,
#                                          'time': '2023-07-21 09:00',
#                                          'time_epoch': 1689955200,
#                                          'uv': 7,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 331,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 10.4,
#                                          'wind_mph': 6.5,
#                                          'windchill_c': 29.1,
#                                          'windchill_f': 84.4},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.6,
#                                          'dewpoint_f': 60.1,
#                                          'feelslike_c': 32.2,
#                                          'feelslike_f': 90.0,
#                                          'gust_kph': 13.0,
#                                          'gust_mph': 8,
#                                          'heatindex_c': 32.2,
#                                          'heatindex_f': 90.0,
#                                          'humidity': 38,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.91,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 31.8,
#                                          'temp_f': 89.2,
#                                          'time': '2023-07-21 10:00',
#                                          'time_epoch': 1689958800,
#                                          'uv': 8,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 314,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 11.2,
#                                          'wind_mph': 6.9,
#                                          'windchill_c': 31.8,
#                                          'windchill_f': 89.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.4,
#                                          'dewpoint_f': 63.3,
#                                          'feelslike_c': 39.3,
#                                          'feelslike_f': 102.7,
#                                          'gust_kph': 13.7,
#                                          'gust_mph': 8,
#                                          'heatindex_c': 39.3,
#                                          'heatindex_f': 102.7,
#                                          'humidity': 31,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.89,
#                                          'pressure_mb': 1012,
#                                          'temp_c': 37.2,
#                                          'temp_f': 99.0,
#                                          'time': '2023-07-21 11:00',
#                                          'time_epoch': 1689962400,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 307,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 11.9,
#                                          'wind_mph': 7.4,
#                                          'windchill_c': 37.2,
#                                          'windchill_f': 99.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 14.6,
#                                          'dewpoint_f': 58.3,
#                                          'feelslike_c': 37.4,
#                                          'feelslike_f': 99.3,
#                                          'gust_kph': 15.5,
#                                          'gust_mph': 9,
#                                          'heatindex_c': 37.4,
#                                          'heatindex_f': 99.3,
#                                          'humidity': 26,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.87,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 37.0,
#                                          'temp_f': 98.6,
#                                          'time': '2023-07-21 12:00',
#                                          'time_epoch': 1689966000,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 303,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 13.3,
#                                          'wind_mph': 8.3,
#                                          'windchill_c': 37.0,
#                                          'windchill_f': 98.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 12,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 13.3,
#                                          'dewpoint_f': 55.9,
#                                          'feelslike_c': 37.8,
#                                          'feelslike_f': 100.0,
#                                          'gust_kph': 18.7,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 37.8,
#                                          'heatindex_f': 100.0,
#                                          'humidity': 23,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 37.9,
#                                          'temp_f': 100.2,
#                                          'time': '2023-07-21 13:00',
#                                          'time_epoch': 1689969600,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 295,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 16.2,
#                                          'wind_mph': 10.1,
#                                          'windchill_c': 37.9,
#                                          'windchill_f': 100.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 8,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.2,
#                                          'dewpoint_f': 59.4,
#                                          'feelslike_c': 43.8,
#                                          'feelslike_f': 110.8,
#                                          'gust_kph': 21.2,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 43.8,
#                                          'heatindex_f': 110.8,
#                                          'humidity': 21,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 42.3,
#                                          'temp_f': 108.1,
#                                          'time': '2023-07-21 14:00',
#                                          'time_epoch': 1689973200,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 296,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 18.4,
#                                          'wind_mph': 11.4,
#                                          'windchill_c': 42.3,
#                                          'windchill_f': 108.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 14.2,
#                                          'dewpoint_f': 57.6,
#                                          'feelslike_c': 44.9,
#                                          'feelslike_f': 112.8,
#                                          'gust_kph': 22.0,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 44.9,
#                                          'heatindex_f': 112.8,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.79,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 43.2,
#                                          'temp_f': 109.8,
#                                          'time': '2023-07-21 15:00',
#                                          'time_epoch': 1689976800,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 303,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 19.1,
#                                          'wind_mph': 11.9,
#                                          'windchill_c': 43.2,
#                                          'windchill_f': 109.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 13.2,
#                                          'dewpoint_f': 55.8,
#                                          'feelslike_c': 45.9,
#                                          'feelslike_f': 114.6,
#                                          'gust_kph': 23.0,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 45.9,
#                                          'heatindex_f': 114.6,
#                                          'humidity': 17,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.76,
#                                          'pressure_mb': 1008,
#                                          'temp_c': 43.8,
#                                          'temp_f': 110.8,
#                                          'time': '2023-07-21 16:00',
#                                          'time_epoch': 1689980400,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 309,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 20.2,
#                                          'wind_mph': 12.5,
#                                          'windchill_c': 43.8,
#                                          'windchill_f': 110.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 8,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.8,
#                                          'dewpoint_f': 53.2,
#                                          'feelslike_c': 45.4,
#                                          'feelslike_f': 113.7,
#                                          'gust_kph': 24.8,
#                                          'gust_mph': 15,
#                                          'heatindex_c': 45.4,
#                                          'heatindex_f': 113.7,
#                                          'humidity': 16,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.74,
#                                          'pressure_mb': 1007,
#                                          'temp_c': 43.5,
#                                          'temp_f': 110.3,
#                                          'time': '2023-07-21 17:00',
#                                          'time_epoch': 1689984000,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 312,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 21.6,
#                                          'wind_mph': 13.4,
#                                          'windchill_c': 43.5,
#                                          'windchill_f': 110.3},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 16,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 9.5,
#                                          'dewpoint_f': 49.1,
#                                          'feelslike_c': 41.4,
#                                          'feelslike_f': 106.5,
#                                          'gust_kph': 27.0,
#                                          'gust_mph': 16,
#                                          'heatindex_c': 41.4,
#                                          'heatindex_f': 106.5,
#                                          'humidity': 15,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.72,
#                                          'pressure_mb': 1007,
#                                          'temp_c': 41.0,
#                                          'temp_f': 105.8,
#                                          'time': '2023-07-21 18:00',
#                                          'time_epoch': 1689987600,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 321,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 23.4,
#                                          'wind_mph': 14.5,
#                                          'windchill_c': 41.0,
#                                          'windchill_f': 105.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 20,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 7.0,
#                                          'dewpoint_f': 44.6,
#                                          'feelslike_c': 42.2,
#                                          'feelslike_f': 108.0,
#                                          'gust_kph': 27.7,
#                                          'gust_mph': 17,
#                                          'heatindex_c': 42.2,
#                                          'heatindex_f': 108.0,
#                                          'humidity': 13,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.67,
#                                          'pressure_mb': 1005,
#                                          'temp_c': 41.5,
#                                          'temp_f': 106.7,
#                                          'time': '2023-07-21 19:00',
#                                          'time_epoch': 1689991200,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 324,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 24.1,
#                                          'wind_mph': 15.0,
#                                          'windchill_c': 41.5,
#                                          'windchill_f': 106.7},
#                                         {'chance_of_rain': 71,
#                                          'chance_of_snow': 0,
#                                          'cloud': 77,
#                                          'condition': {'code': 1063,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#                                                        'text': 'Patchy rain '
#                                                                'possible'},
#                                          'dewpoint_c': 8.4,
#                                          'dewpoint_f': 47.1,
#                                          'feelslike_c': 39.5,
#                                          'feelslike_f': 103.1,
#                                          'gust_kph': 18.0,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 39.5,
#                                          'heatindex_f': 103.1,
#                                          'humidity': 15,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.7,
#                                          'pressure_mb': 1006,
#                                          'temp_c': 39.7,
#                                          'temp_f': 103.5,
#                                          'time': '2023-07-21 20:00',
#                                          'time_epoch': 1689994800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 1,
# ...
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 281,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 14.0,
#                                          'wind_mph': 8.7,
#                                          'windchill_c': 40.5,
#                                          'windchill_f': 104.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.9,
#                                          'dewpoint_f': 53.4,
#                                          'feelslike_c': 39.6,
#                                          'feelslike_f': 103.3,
#                                          'gust_kph': 18.7,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 39.6,
#                                          'heatindex_f': 103.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 39.7,
#                                          'temp_f': 103.5,
#                                          'time': '2023-08-03 17:00',
#                                          'time_epoch': 1691107200,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 293,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 16.2,
#                                          'wind_mph': 10.1,
#                                          'windchill_c': 39.7,
#                                          'windchill_f': 103.5},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.0,
#                                          'dewpoint_f': 51.8,
#                                          'feelslike_c': 38.5,
#                                          'feelslike_f': 101.3,
#                                          'gust_kph': 21.6,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 38.5,
#                                          'heatindex_f': 101.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.8,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 39.0,
#                                          'temp_f': 102.2,
#                                          'time': '2023-08-03 18:00',
#                                          'time_epoch': 1691110800,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 305,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 18.7,
#                                          'wind_mph': 11.6,
#                                          'windchill_c': 39.0,
#                                          'windchill_f': 102.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 10.7,
#                                          'dewpoint_f': 51.3,
#                                          'feelslike_c': 37.4,
#                                          'feelslike_f': 99.3,
#                                          'gust_kph': 22.7,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 37.4,
#                                          'heatindex_f': 99.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 38.2,
#                                          'temp_f': 100.8,
#                                          'time': '2023-08-03 19:00',
#                                          'time_epoch': 1691114400,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 311,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 19.8,
#                                          'wind_mph': 12.3,
#                                          'windchill_c': 38.2,
#                                          'windchill_f': 100.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.3,
#                                          'dewpoint_f': 50.5,
#                                          'feelslike_c': 36.2,
#                                          'feelslike_f': 97.2,
#                                          'gust_kph': 23.8,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 36.2,
#                                          'heatindex_f': 97.2,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.83,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 37.3,
#                                          'temp_f': 99.1,
#                                          'time': '2023-08-03 20:00',
#                                          'time_epoch': 1691118000,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 318,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 20.5,
#                                          'wind_mph': 12.8,
#                                          'windchill_c': 37.3,
#                                          'windchill_f': 99.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 35.1,
#                                          'feelslike_f': 95.2,
#                                          'gust_kph': 24.8,
#                                          'gust_mph': 15,
#                                          'heatindex_c': 35.1,
#                                          'heatindex_f': 95.2,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 36.5,
#                                          'temp_f': 97.7,
#                                          'time': '2023-08-03 21:00',
#                                          'time_epoch': 1691121600,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 325,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 21.6,
#                                          'wind_mph': 13.4,
#                                          'windchill_c': 36.5,
#                                          'windchill_f': 97.7},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 34.2,
#                                          'feelslike_f': 93.6,
#                                          'gust_kph': 20.5,
#                                          'gust_mph': 12,
#                                          'heatindex_c': 34.2,
#                                          'heatindex_f': 93.6,
#                                          'humidity': 21,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.85,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 35.6,
#                                          'temp_f': 96.1,
#                                          'time': '2023-08-03 22:00',
#                                          'time_epoch': 1691125200,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 326,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 17.3,
#                                          'wind_mph': 10.7,
#                                          'windchill_c': 35.6,
#                                          'windchill_f': 96.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 9,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 33.2,
#                                          'feelslike_f': 91.8,
#                                          'gust_kph': 15.8,
#                                          'gust_mph': 9,
#                                          'heatindex_c': 33.2,
#                                          'heatindex_f': 91.8,
#                                          'humidity': 22,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.87,
#                                          'pressure_mb': 1012,
#                                          'temp_c': 34.7,
#                                          'temp_f': 94.5,
#                                          'time': '2023-08-03 23:00',
#                                          'time_epoch': 1691128800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 328,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 13.0,
#                                          'wind_mph': 8.1,
#                                          'windchill_c': 34.7,
#                                          'windchill_f': 94.5}]}]},
#  'location': {'country': 'United States of America',
#               'lat': 32.22,
#               'localtime': '2023-07-21 22:18',
#               'localtime_epoch': 1690003135,
#               'lon': -110.93,
#               'name': 'Tucson',
#               'region': 'Arizona',
#               'tz_id': 'America/Phoenix'}}

# %%
# This doesnt work since its not returning in manner that can be decoded to a json
api_test_json = api_response.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 api_test_json = api_response.json()
#
# AttributeError: 'InlineResponse2001' object has no attribute 'json'

# %%
api_response
#just prints out what is in the object
# Out:
# {'alerts': None,
#  'current': {'air_quality': None,
#              'cloud': 50,
#              'condition': {'code': 1003,
#                            'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                            'text': 'Partly cloudy'},
#              'feelslike_c': 33,
#              'feelslike_f': 91.8,
#              'gust_kph': 43.6,
#              'gust_mph': 27.1,
#              'humidity': 34,
#              'is_day': 0,
#              'last_updated': '2023-07-21 22:15',
#              'last_updated_epoch': 1690002900,
#              'precip_in': 0,
#              'precip_mm': 0,
#              'pressure_in': 29.97,
#              'pressure_mb': 1015,
#              'temp_c': 31.7,
#              'temp_f': 89.1,
#              'uv': 1,
#              'vis_km': 16,
#              'vis_miles': 9,
#              'wind_degree': 190,
#              'wind_dir': 'S',
#              'wind_kph': 38.9,
#              'wind_mph': 24.2},
#  'forecast': {'forecastday': [{'_date': datetime.date(2023, 7, 21),
#                                'astro': {'moon_illumination': '9',
#                                          'moon_phase': 'Waxing Crescent',
#                                          'moonrise': '08:56 AM',
#                                          'moonset': '10:04 PM',
#                                          'sunrise': '05:32 AM',
#                                          'sunset': '07:29 PM'},
#                                'date_epoch': 1689897600,
#                                'day': {'avghumidity': 30,
#                                        'avgtemp_c': 34.1,
#                                        'avgtemp_f': 93.4,
#                                        'avgvis_km': 9,
#                                        'avgvis_miles': 6,
#                                        'condition': {'code': 1063,
#                                                      'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#                                                      'text': 'Patchy rain '
#                                                              'possible'},
#                                        'daily_chance_of_rain': 88,
#                                        'daily_chance_of_snow': 0,
#                                        'daily_will_it_rain': 1,
#                                        'daily_will_it_snow': 0,
#                                        'maxtemp_c': 43.8,
#                                        'maxtemp_f': 110.8,
#                                        'maxwind_kph': 36.7,
#                                        'maxwind_mph': 22.8,
#                                        'mintemp_c': 24.7,
#                                        'mintemp_f': 76.5,
#                                        'totalprecip_in': 0,
#                                        'totalprecip_mm': 0,
#                                        'uv': 7},
#                                'hour': [{'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 4,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 5.9,
#                                          'dewpoint_f': 42.6,
#                                          'feelslike_c': 31.2,
#                                          'feelslike_f': 88.2,
#                                          'gust_kph': 10.8,
#                                          'gust_mph': 6,
#                                          'heatindex_c': 31.2,
#                                          'heatindex_f': 88.2,
#                                          'humidity': 18,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 33.3,
#                                          'temp_f': 91.9,
#                                          'time': '2023-07-21 00:00',
#                                          'time_epoch': 1689922800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 202,
#                                          'wind_dir': 'SSW',
#                                          'wind_kph': 6.5,
#                                          'wind_mph': 4.0,
#                                          'windchill_c': 33.3,
#                                          'windchill_f': 91.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 11,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 6.3,
#                                          'dewpoint_f': 43.3,
#                                          'feelslike_c': 29.9,
#                                          'feelslike_f': 85.8,
#                                          'gust_kph': 18.4,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 29.9,
#                                          'heatindex_f': 85.8,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.8,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 32.1,
#                                          'temp_f': 89.8,
#                                          'time': '2023-07-21 01:00',
#                                          'time_epoch': 1689926400,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 204,
#                                          'wind_dir': 'SSW',
#                                          'wind_kph': 11.9,
#                                          'wind_mph': 7.4,
#                                          'windchill_c': 32.1,
#                                          'windchill_f': 89.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 14,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 6.6,
#                                          'dewpoint_f': 43.9,
#                                          'feelslike_c': 28.9,
#                                          'feelslike_f': 84.0,
#                                          'gust_kph': 16.6,
#                                          'gust_mph': 10,
#                                          'heatindex_c': 28.9,
#                                          'heatindex_f': 84.0,
#                                          'humidity': 22,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 30.9,
#                                          'temp_f': 87.6,
#                                          'time': '2023-07-21 02:00',
#                                          'time_epoch': 1689930000,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 238,
#                                          'wind_dir': 'WSW',
#                                          'wind_kph': 10.4,
#                                          'wind_mph': 6.5,
#                                          'windchill_c': 30.9,
#                                          'windchill_f': 87.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 38,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Partly cloudy'},
#                                          'dewpoint_c': 6.8,
#                                          'dewpoint_f': 44.2,
#                                          'feelslike_c': 27.8,
#                                          'feelslike_f': 82.0,
#                                          'gust_kph': 18.4,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 27.8,
#                                          'heatindex_f': 82.0,
#                                          'humidity': 24,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 29.6,
#                                          'temp_f': 85.3,
#                                          'time': '2023-07-21 03:00',
#                                          'time_epoch': 1689933600,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 274,
#                                          'wind_dir': 'W',
#                                          'wind_kph': 12.2,
#                                          'wind_mph': 7.6,
#                                          'windchill_c': 29.6,
#                                          'windchill_f': 85.3},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 65,
#                                          'condition': {'code': 1006,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/119.png',
#                                                        'text': 'Cloudy'},
#                                          'dewpoint_c': 7.5,
#                                          'dewpoint_f': 45.5,
#                                          'feelslike_c': 27.3,
#                                          'feelslike_f': 81.1,
#                                          'gust_kph': 9.0,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 27.3,
#                                          'heatindex_f': 81.1,
#                                          'humidity': 26,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 28.8,
#                                          'temp_f': 83.8,
#                                          'time': '2023-07-21 04:00',
#                                          'time_epoch': 1689937200,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 296,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 7.2,
#                                          'wind_mph': 4.5,
#                                          'windchill_c': 28.8,
#                                          'windchill_f': 83.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 44,
#                                          'condition': {'code': 1003,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#                                                        'text': 'Partly cloudy'},
#                                          'dewpoint_c': 11.5,
#                                          'dewpoint_f': 52.7,
#                                          'feelslike_c': 26.7,
#                                          'feelslike_f': 80.1,
#                                          'gust_kph': 7.9,
#                                          'gust_mph': 4,
#                                          'heatindex_c': 26.7,
#                                          'heatindex_f': 80.1,
#                                          'humidity': 38,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.86,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 27.0,
#                                          'temp_f': 80.6,
#                                          'time': '2023-07-21 05:00',
#                                          'time_epoch': 1689940800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 311,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 5.8,
#                                          'wind_mph': 3.6,
#                                          'windchill_c': 27.0,
#                                          'windchill_f': 80.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.9,
#                                          'dewpoint_f': 60.6,
#                                          'feelslike_c': 26.0,
#                                          'feelslike_f': 78.8,
#                                          'gust_kph': 10.4,
#                                          'gust_mph': 6,
#                                          'heatindex_c': 26.0,
#                                          'heatindex_f': 78.8,
#                                          'humidity': 58,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.9,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 24.9,
#                                          'temp_f': 76.8,
#                                          'time': '2023-07-21 06:00',
#                                          'time_epoch': 1689944400,
#                                          'uv': 6,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 346,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 7.6,
#                                          'wind_mph': 4.7,
#                                          'windchill_c': 24.9,
#                                          'windchill_f': 76.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.8,
#                                          'feelslike_c': 26.1,
#                                          'feelslike_f': 79.0,
#                                          'gust_kph': 9.4,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 26.1,
#                                          'heatindex_f': 79.0,
#                                          'humidity': 63,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 24.7,
#                                          'temp_f': 76.5,
#                                          'time': '2023-07-21 07:00',
#                                          'time_epoch': 1689948000,
#                                          'uv': 6,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 356,
#                                          'wind_dir': 'N',
#                                          'wind_kph': 7.2,
#                                          'wind_mph': 4.5,
#                                          'windchill_c': 24.7,
#                                          'windchill_f': 76.5},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.1,
#                                          'dewpoint_f': 62.8,
#                                          'feelslike_c': 27.8,
#                                          'feelslike_f': 82.0,
#                                          'gust_kph': 9.4,
#                                          'gust_mph': 5,
#                                          'heatindex_c': 27.8,
#                                          'heatindex_f': 82.0,
#                                          'humidity': 56,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 26.8,
#                                          'temp_f': 80.2,
#                                          'time': '2023-07-21 08:00',
#                                          'time_epoch': 1689951600,
#                                          'uv': 7,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 347,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 8.3,
#                                          'wind_mph': 5.1,
#                                          'windchill_c': 26.8,
#                                          'windchill_f': 80.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 16.2,
#                                          'dewpoint_f': 61.2,
#                                          'feelslike_c': 29.6,
#                                          'feelslike_f': 85.3,
#                                          'gust_kph': 11.9,
#                                          'gust_mph': 7,
#                                          'heatindex_c': 29.6,
#                                          'heatindex_f': 85.3,
#                                          'humidity': 46,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.92,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 29.1,
#                                          'temp_f': 84.4,
#                                          'time': '2023-07-21 09:00',
#                                          'time_epoch': 1689955200,
#                                          'uv': 7,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 331,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 10.4,
#                                          'wind_mph': 6.5,
#                                          'windchill_c': 29.1,
#                                          'windchill_f': 84.4},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.6,
#                                          'dewpoint_f': 60.1,
#                                          'feelslike_c': 32.2,
#                                          'feelslike_f': 90.0,
#                                          'gust_kph': 13.0,
#                                          'gust_mph': 8,
#                                          'heatindex_c': 32.2,
#                                          'heatindex_f': 90.0,
#                                          'humidity': 38,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.91,
#                                          'pressure_mb': 1013,
#                                          'temp_c': 31.8,
#                                          'temp_f': 89.2,
#                                          'time': '2023-07-21 10:00',
#                                          'time_epoch': 1689958800,
#                                          'uv': 8,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 314,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 11.2,
#                                          'wind_mph': 6.9,
#                                          'windchill_c': 31.8,
#                                          'windchill_f': 89.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 17.4,
#                                          'dewpoint_f': 63.3,
#                                          'feelslike_c': 39.3,
#                                          'feelslike_f': 102.7,
#                                          'gust_kph': 13.7,
#                                          'gust_mph': 8,
#                                          'heatindex_c': 39.3,
#                                          'heatindex_f': 102.7,
#                                          'humidity': 31,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.89,
#                                          'pressure_mb': 1012,
#                                          'temp_c': 37.2,
#                                          'temp_f': 99.0,
#                                          'time': '2023-07-21 11:00',
#                                          'time_epoch': 1689962400,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 307,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 11.9,
#                                          'wind_mph': 7.4,
#                                          'windchill_c': 37.2,
#                                          'windchill_f': 99.0},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 14.6,
#                                          'dewpoint_f': 58.3,
#                                          'feelslike_c': 37.4,
#                                          'feelslike_f': 99.3,
#                                          'gust_kph': 15.5,
#                                          'gust_mph': 9,
#                                          'heatindex_c': 37.4,
#                                          'heatindex_f': 99.3,
#                                          'humidity': 26,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.87,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 37.0,
#                                          'temp_f': 98.6,
#                                          'time': '2023-07-21 12:00',
#                                          'time_epoch': 1689966000,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 303,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 13.3,
#                                          'wind_mph': 8.3,
#                                          'windchill_c': 37.0,
#                                          'windchill_f': 98.6},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 12,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 13.3,
#                                          'dewpoint_f': 55.9,
#                                          'feelslike_c': 37.8,
#                                          'feelslike_f': 100.0,
#                                          'gust_kph': 18.7,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 37.8,
#                                          'heatindex_f': 100.0,
#                                          'humidity': 23,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 37.9,
#                                          'temp_f': 100.2,
#                                          'time': '2023-07-21 13:00',
#                                          'time_epoch': 1689969600,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 295,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 16.2,
#                                          'wind_mph': 10.1,
#                                          'windchill_c': 37.9,
#                                          'windchill_f': 100.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 8,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 15.2,
#                                          'dewpoint_f': 59.4,
#                                          'feelslike_c': 43.8,
#                                          'feelslike_f': 110.8,
#                                          'gust_kph': 21.2,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 43.8,
#                                          'heatindex_f': 110.8,
#                                          'humidity': 21,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 42.3,
#                                          'temp_f': 108.1,
#                                          'time': '2023-07-21 14:00',
#                                          'time_epoch': 1689973200,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 296,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 18.4,
#                                          'wind_mph': 11.4,
#                                          'windchill_c': 42.3,
#                                          'windchill_f': 108.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 14.2,
#                                          'dewpoint_f': 57.6,
#                                          'feelslike_c': 44.9,
#                                          'feelslike_f': 112.8,
#                                          'gust_kph': 22.0,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 44.9,
#                                          'heatindex_f': 112.8,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.79,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 43.2,
#                                          'temp_f': 109.8,
#                                          'time': '2023-07-21 15:00',
#                                          'time_epoch': 1689976800,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 303,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 19.1,
#                                          'wind_mph': 11.9,
#                                          'windchill_c': 43.2,
#                                          'windchill_f': 109.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 0,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 13.2,
#                                          'dewpoint_f': 55.8,
#                                          'feelslike_c': 45.9,
#                                          'feelslike_f': 114.6,
#                                          'gust_kph': 23.0,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 45.9,
#                                          'heatindex_f': 114.6,
#                                          'humidity': 17,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.76,
#                                          'pressure_mb': 1008,
#                                          'temp_c': 43.8,
#                                          'temp_f': 110.8,
#                                          'time': '2023-07-21 16:00',
#                                          'time_epoch': 1689980400,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 309,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 20.2,
#                                          'wind_mph': 12.5,
#                                          'windchill_c': 43.8,
#                                          'windchill_f': 110.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 8,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.8,
#                                          'dewpoint_f': 53.2,
#                                          'feelslike_c': 45.4,
#                                          'feelslike_f': 113.7,
#                                          'gust_kph': 24.8,
#                                          'gust_mph': 15,
#                                          'heatindex_c': 45.4,
#                                          'heatindex_f': 113.7,
#                                          'humidity': 16,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.74,
#                                          'pressure_mb': 1007,
#                                          'temp_c': 43.5,
#                                          'temp_f': 110.3,
#                                          'time': '2023-07-21 17:00',
#                                          'time_epoch': 1689984000,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 312,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 21.6,
#                                          'wind_mph': 13.4,
#                                          'windchill_c': 43.5,
#                                          'windchill_f': 110.3},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 16,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 9.5,
#                                          'dewpoint_f': 49.1,
#                                          'feelslike_c': 41.4,
#                                          'feelslike_f': 106.5,
#                                          'gust_kph': 27.0,
#                                          'gust_mph': 16,
#                                          'heatindex_c': 41.4,
#                                          'heatindex_f': 106.5,
#                                          'humidity': 15,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.72,
#                                          'pressure_mb': 1007,
#                                          'temp_c': 41.0,
#                                          'temp_f': 105.8,
#                                          'time': '2023-07-21 18:00',
#                                          'time_epoch': 1689987600,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 321,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 23.4,
#                                          'wind_mph': 14.5,
#                                          'windchill_c': 41.0,
#                                          'windchill_f': 105.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 20,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 7.0,
#                                          'dewpoint_f': 44.6,
#                                          'feelslike_c': 42.2,
#                                          'feelslike_f': 108.0,
#                                          'gust_kph': 27.7,
#                                          'gust_mph': 17,
#                                          'heatindex_c': 42.2,
#                                          'heatindex_f': 108.0,
#                                          'humidity': 13,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.67,
#                                          'pressure_mb': 1005,
#                                          'temp_c': 41.5,
#                                          'temp_f': 106.7,
#                                          'time': '2023-07-21 19:00',
#                                          'time_epoch': 1689991200,
#                                          'uv': 10,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 324,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 24.1,
#                                          'wind_mph': 15.0,
#                                          'windchill_c': 41.5,
#                                          'windchill_f': 106.7},
#                                         {'chance_of_rain': 71,
#                                          'chance_of_snow': 0,
#                                          'cloud': 77,
#                                          'condition': {'code': 1063,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#                                                        'text': 'Patchy rain '
#                                                                'possible'},
#                                          'dewpoint_c': 8.4,
#                                          'dewpoint_f': 47.1,
#                                          'feelslike_c': 39.5,
#                                          'feelslike_f': 103.1,
#                                          'gust_kph': 18.0,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 39.5,
#                                          'heatindex_f': 103.1,
#                                          'humidity': 15,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.7,
#                                          'pressure_mb': 1006,
#                                          'temp_c': 39.7,
#                                          'temp_f': 103.5,
#                                          'time': '2023-07-21 20:00',
#                                          'time_epoch': 1689994800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 1,
# ...
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 281,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 14.0,
#                                          'wind_mph': 8.7,
#                                          'windchill_c': 40.5,
#                                          'windchill_f': 104.9},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.9,
#                                          'dewpoint_f': 53.4,
#                                          'feelslike_c': 39.6,
#                                          'feelslike_f': 103.3,
#                                          'gust_kph': 18.7,
#                                          'gust_mph': 11,
#                                          'heatindex_c': 39.6,
#                                          'heatindex_f': 103.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.82,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 39.7,
#                                          'temp_f': 103.5,
#                                          'time': '2023-08-03 17:00',
#                                          'time_epoch': 1691107200,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 293,
#                                          'wind_dir': 'WNW',
#                                          'wind_kph': 16.2,
#                                          'wind_mph': 10.1,
#                                          'windchill_c': 39.7,
#                                          'windchill_f': 103.5},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 11.0,
#                                          'dewpoint_f': 51.8,
#                                          'feelslike_c': 38.5,
#                                          'feelslike_f': 101.3,
#                                          'gust_kph': 21.6,
#                                          'gust_mph': 13,
#                                          'heatindex_c': 38.5,
#                                          'heatindex_f': 101.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.8,
#                                          'pressure_mb': 1009,
#                                          'temp_c': 39.0,
#                                          'temp_f': 102.2,
#                                          'time': '2023-08-03 18:00',
#                                          'time_epoch': 1691110800,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 305,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 18.7,
#                                          'wind_mph': 11.6,
#                                          'windchill_c': 39.0,
#                                          'windchill_f': 102.2},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#                                                        'text': 'Sunny'},
#                                          'dewpoint_c': 10.7,
#                                          'dewpoint_f': 51.3,
#                                          'feelslike_c': 37.4,
#                                          'feelslike_f': 99.3,
#                                          'gust_kph': 22.7,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 37.4,
#                                          'heatindex_f': 99.3,
#                                          'humidity': 19,
#                                          'is_day': 1,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.81,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 38.2,
#                                          'temp_f': 100.8,
#                                          'time': '2023-08-03 19:00',
#                                          'time_epoch': 1691114400,
#                                          'uv': 9,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 311,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 19.8,
#                                          'wind_mph': 12.3,
#                                          'windchill_c': 38.2,
#                                          'windchill_f': 100.8},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.3,
#                                          'dewpoint_f': 50.5,
#                                          'feelslike_c': 36.2,
#                                          'feelslike_f': 97.2,
#                                          'gust_kph': 23.8,
#                                          'gust_mph': 14,
#                                          'heatindex_c': 36.2,
#                                          'heatindex_f': 97.2,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.83,
#                                          'pressure_mb': 1010,
#                                          'temp_c': 37.3,
#                                          'temp_f': 99.1,
#                                          'time': '2023-08-03 20:00',
#                                          'time_epoch': 1691118000,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 318,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 20.5,
#                                          'wind_mph': 12.8,
#                                          'windchill_c': 37.3,
#                                          'windchill_f': 99.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 5,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 35.1,
#                                          'feelslike_f': 95.2,
#                                          'gust_kph': 24.8,
#                                          'gust_mph': 15,
#                                          'heatindex_c': 35.1,
#                                          'heatindex_f': 95.2,
#                                          'humidity': 20,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.84,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 36.5,
#                                          'temp_f': 97.7,
#                                          'time': '2023-08-03 21:00',
#                                          'time_epoch': 1691121600,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 325,
#                                          'wind_dir': 'NW',
#                                          'wind_kph': 21.6,
#                                          'wind_mph': 13.4,
#                                          'windchill_c': 36.5,
#                                          'windchill_f': 97.7},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 7,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 34.2,
#                                          'feelslike_f': 93.6,
#                                          'gust_kph': 20.5,
#                                          'gust_mph': 12,
#                                          'heatindex_c': 34.2,
#                                          'heatindex_f': 93.6,
#                                          'humidity': 21,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.85,
#                                          'pressure_mb': 1011,
#                                          'temp_c': 35.6,
#                                          'temp_f': 96.1,
#                                          'time': '2023-08-03 22:00',
#                                          'time_epoch': 1691125200,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 326,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 17.3,
#                                          'wind_mph': 10.7,
#                                          'windchill_c': 35.6,
#                                          'windchill_f': 96.1},
#                                         {'chance_of_rain': 0,
#                                          'chance_of_snow': 0,
#                                          'cloud': 9,
#                                          'condition': {'code': 1000,
#                                                        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#                                                        'text': 'Clear'},
#                                          'dewpoint_c': 10.0,
#                                          'dewpoint_f': 50.0,
#                                          'feelslike_c': 33.2,
#                                          'feelslike_f': 91.8,
#                                          'gust_kph': 15.8,
#                                          'gust_mph': 9,
#                                          'heatindex_c': 33.2,
#                                          'heatindex_f': 91.8,
#                                          'humidity': 22,
#                                          'is_day': 0,
#                                          'precip_in': 0,
#                                          'precip_mm': 0,
#                                          'pressure_in': 29.87,
#                                          'pressure_mb': 1012,
#                                          'temp_c': 34.7,
#                                          'temp_f': 94.5,
#                                          'time': '2023-08-03 23:00',
#                                          'time_epoch': 1691128800,
#                                          'uv': 1,
#                                          'vis_km': 10,
#                                          'vis_miles': 6,
#                                          'will_it_rain': 0,
#                                          'will_it_snow': 0,
#                                          'wind_degree': 328,
#                                          'wind_dir': 'NNW',
#                                          'wind_kph': 13.0,
#                                          'wind_mph': 8.1,
#                                          'windchill_c': 34.7,
#                                          'windchill_f': 94.5}]}]},
#  'location': {'country': 'United States of America',
#               'lat': 32.22,
#               'localtime': '2023-07-21 22:18',
#               'localtime_epoch': 1690003135,
#               'lon': -110.93,
#               'name': 'Tucson',
#               'region': 'Arizona',
#               'tz_id': 'America/Phoenix'}}

# %%
type(api_response)
# Out:
# swagger_client.models.inline_response2001.InlineResponse2001

# %%
string_api = str(api_response)

# %%
string_api
#checks to make sure that the object is a string (Je deviens paro (Alo, alo, alo, paro paro...?))
# Out:
# "{'alerts': None,\n 'current': {'air_quality': None,\n             'cloud': 50,\n             'condition': {'code': 1003,\n                           'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',\n                           'text': 'Partly cloudy'},\n             'feelslike_c': 33,\n             'feelslike_f': 91.8,\n             'gust_kph': 43.6,\n             'gust_mph': 27.1,\n             'humidity': 34,\n             'is_day': 0,\n             'last_updated': '2023-07-21 22:15',\n             'last_updated_epoch': 1690002900,\n             'precip_in': 0,\n             'precip_mm': 0,\n             'pressure_in': 29.97,\n             'pressure_mb': 1015,\n             'temp_c': 31.7,\n             'temp_f': 89.1,\n             'uv': 1,\n             'vis_km': 16,\n             'vis_miles': 9,\n             'wind_degree': 190,\n             'wind_dir': 'S',\n             'wind_kph': 38.9,\n             'wind_mph': 24.2},\n 'forecast': {'forecastday': [{'_date': datetime.date(2023, 7, 21),\n                               'astro': {'moon_illumination': '9',\n                                         'moon_phase': 'Waxing Crescent',\n                                         'moonrise': '08:56 AM',\n                                         'moonset': '10:04 PM',\n                                         'sunrise': '05:32 AM',\n                                         'sunset': '07:29 PM'},\n                               'date_epoch': 1689897600,\n                               'day': {'avghumidity': 30,\n                                       'avgtemp_c': 34.1,\n                                       'avgtemp_f': 93.4,\n                                       'avgvis_km': 9,\n                                       'avgvis_miles': 6,\n                                       'condition': {'code': 1063,\n                                                     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',\n                                                     'text': 'Patchy rain '\n                                                             'possible'},\n                                       'daily_chance_of_rain': 88,\n                                       'daily_chance_of_snow': 0,\n                                       'daily_will_it_rain': 1,\n                                       'daily_will_it_snow': 0,\n                                       'maxtemp_c': 43.8,\n                                       'maxtemp_f': 110.8,\n                                       'maxwind_kph': 36.7,\n                                       'maxwind_mph': 22.8,\n                                       'mintemp_c': 24.7,\n                                       'mintemp_f': 76.5,\n                                       'totalprecip_in': 0,\n                                       'totalprecip_mm': 0,\n                                       'uv': 7},\n                               'hour': [{'chance_of_rain': 0,\n                                         'chance_of_snow': 0,\n                                         'cloud': 4,\n                                         'condition': {'code': 1000,\n                                                       'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',\n                                                       'text': 'Clear'},\n                                         'dewpoint_c': 5.9,\n                                         'dewpoint_f': 42.6,\n                                         'feelslike_c': 31.2,\n                                         'feelslike_f': 88.2,\n                                         'gust_kph': 10.8,\n                                         'gust_mph': 6,\n                                         'heatindex_c': 31.2,\n                                         'heatindex_f': 88.2,\n                                         'humidity': 18,\n                                         'is_day': 0,\n                                         'precip_i ...

# %%
# loading file doesnt work this way
json_object = json.loads(string_api)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 json_object = json.loads(string_api)
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
#trying to load file again
f = open('C:/Users/delta/Documents/U of A/Other/Hackathon/Accesshack2023/stuffs.json', 'r')
print(f)
i = json.load(f)
# Out:
# <_io.TextIOWrapper name='C:/Users/delta/Documents/U of A/Other/Hackathon/Accesshack2023/stuffs.json' mode='r' encoding='cp1252'>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[34], line 4
#       2 f = open('C:/Users/delta/Documents/U of A/Other/Hackathon/Accesshack2023/stuffs.json', 'r')
#       3 print(f)
# ----> 4 i = json.load(f)
#
# File ~\anaconda3\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %% [markdown]
# It appears the json i made manually i made wrong. Hecc
